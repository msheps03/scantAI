# %% [markdown]
# ### Remove Background

# %%
# wtf

from PIL import Image, ImageOps
from rembg import remove
import os
import pandas as pd

input_path = '/Users/shep/Documents/Graphing/test/0down.jpg' # input image path
output_path = '/Users/shep/Documents/Graphing/test/output.png' # output image path

input = Image.open(input_path) # load image
output = remove(input)
output.save(output_path) # save image
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[57], line 6
#       4 from rembg import remove
#       5 import os
# ----> 6 import pandas as pd
#       8 input_path = '/Users/shep/Documents/Graphing/test/0down.jpg' # input image path
#       9 output_path = '/Users/shep/Documents/Graphing/test/output.png' # output image path
#
# ModuleNotFoundError: No module named 'pandas'

# %% [markdown]
# ### Rotate

# %%
rate = 45
rotated_ims = []
for i in range(0,360, rate):
  rotated_ims.append(output.rotate(i))



'''
for i in rotated_ims:
  i.show()'''

# %% [markdown]
# ### Cycle Background

# %%
from PIL import ImageOps
#for backPath in os.listdir('./backgrounds/'):
back_im = Image.open('/Users/shep/Documents/Graphing/backgrounds/clear_arm.jpg')
output = remove(Image.open('/Users/shep/Documents/Graphing/test/0down.jpg')) # load image

x, y = back_im.size # get shape
x2, y2 = output.size
print(x2,y2)
#tups = 
xx = output.resize((int(x), int(y)))
print(xx.size)
xxx = xx.rotate(90)
new_back_im=back_im.resize((int(2*x),int(2*y)))
x, y = new_back_im.size # get shape
x2, y2 = xxx.size
xxx.show()
new_back_im.show()
new_back_im.paste(xxx, (int(x/2)-int(x2/2), int(y/2)-int(y2/2)),xxx ) # paste at center of image
new_back_im.show()
# Out:
# 3648 2736
# (522, 331)

# %%
from PIL import ImageOps
#for backPath in os.listdir('./backgrounds/'):
back_im = Image.open('/Users/shep/Documents/Graphing/backgrounds/clear_arm.jpg')
output = remove(Image.open('/Users/shep/Documents/Graphing/test/0down.jpg')) # load image

x, y = back_im.size # get shape
x2, y2 = output.size
print(x2,y2)
#tups = 
xx = output.resize((int(x), int(y)))
print(xx.size)
xxx = xx.rotate(90)
new_back_im=back_im.resize((int(2*x),int(2*y)))
x, y = new_back_im.size # get shape
x2, y2 = xxx.size
xxx.show()
new_back_im.show()
new_back_im.paste(xxx, (int(x/2)-int(x2/2), int(y/2)-int(y2/2)),xxx ) # paste at center of image
new_back_im.show()
# Out:
# 3648 2736
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[58], line 10
#       8 print(x2,y2)
#       9 #tups =
# ---> 10 xx = output.resize((int(x), int(y)))
#      11 print(xx.size)
#      12 xxx = xx.rotate(90)
#
# File ~/opt/anaconda3/envs/Images/lib/python3.9/site-packages/PIL/Image.py:2169, in Image.resize(self, size, resample, box, reducing_gap)
#    2166     resample = Resampling.NEAREST
#    2168 if self.mode in ["LA", "RGBA"] and resample != Resampling.NEAREST:
# -> 2169     im = self.convert({"LA": "La", "RGBA": "RGBa"}[self.mode])
#    2170     im = im.resize(size, resample, box)
#    2171     return im.convert(self.mode)
#
# File ~/opt/anaconda3/envs/Images/lib/python3.9/site-packages/PIL/Image.py:1081, in Image.convert(self, mode, matrix, dither, palette, colors)
#    1078     dither = Dither.FLOYDSTEINBERG
#    1080 try:
# ...

# %%
back_im.resize(back_im.size)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 back_im.resize(2*back_im.size)
#
# File ~/opt/anaconda3/envs/Images/lib/python3.9/site-packages/PIL/Image.py:2192, in Image.resize(self, size, resample, box, reducing_gap)
#    2184             self = Image.reduce(self, factor, box=reduce_box)
#    2185         box = (
#    2186             (box[0] - reduce_box[0]) / factor_x,
#    2187             (box[1] - reduce_box[1]) / factor_y,
#    2188             (box[2] - reduce_box[0]) / factor_x,
#    2189             (box[3] - reduce_box[1]) / factor_y,
#    2190         )
# -> 2192 return self._new(self.im.resize(size, resample, box))
#
# TypeError: argument 1 must be sequence of length 2, not 4

# %%
# !pip install rembg
# Out:
# ...
#   Using cached rembg-2.0.32-py3-none-any.whl (14 kB)
# ...
#   Using cached aiohttp-3.8.4-cp310-cp310-win_amd64.whl (319 kB)
# ...
#   Using cached click-8.1.3-py3-none-any.whl (96 kB)
# ...
#   Using cached scikit_image-0.20.0-cp310-cp310-win_amd64.whl (23.7 MB)
# ...
#   Using cached PyMatting-1.1.8-py3-none-any.whl (47 kB)
# ...
#   Using cached ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
# ...
#   Using cached asyncer-0.0.2-py3-none-any.whl (8.3 kB)
# ...
#   Using cached uvicorn-0.21.1-py3-none-any.whl (57 kB)
# ...
#   Using cached pooch-1.7.0-py3-none-any.whl (60 kB)
# ...
#   Using cached onnxruntime-1.14.1-cp310-cp310-win_amd64.whl (6.5 MB)
# ...
#   Using cached opencv_python_headless-4.7.0.72-cp37-abi3-win_amd64.whl (38.1 MB)
# ...
#   Using cached fastapi-0.95.0-py3-none-any.whl (57 kB)
# ...
#   Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# ...
#   Using cached multidict-6.0.4-cp310-cp310-win_amd64.whl (28 kB)
# ...
#   Using cached frozenlist-1.3.3-cp310-cp310-win_amd64.whl (33 kB)
# ...

# %%
import os
import pandas as pd
from PIL import Image, ImageOps
from rembg import remove
df = pd.read_csv('sexy.csv')

rate = 45
rotated_ims = []



for ID in df.index:
    tick = df2.iloc[ID]['name']
    numba = df2.iloc[ID]['number']
    #tick = df.iloc['name'][ID]
    fileName = str(numba)+'top.jpg'
    
    output = remove(Image.open('C:/Users/ShepDaddy/Documents/GitHub/scantAI/augmented/test/'+fileName))
    try:
        for rotation in range(0,360, rate):
            newput = output.rotate(rotation)
            for i in os.listdir('C:/Users/ShepDaddy/Documents/GitHub/scantAI/augmented/scant_backgrounds/'):
                back_name = i.split('.')[0]
                back_im = Image.open('C:/Users/ShepDaddy/Documents/GitHub/scantAI/augmented/scant_backgrounds/'+i)
                #print(i, ':', cur.size, '\n')
                x, y = back_im.size # get shape
                x2, y2 = newput.size
                #print(x2,y2)
                #tups = 
                xxx = newput.resize((int(x), int(y)))
                #print(xx.size)
                
                new_back_im=back_im.resize((int(2*x),int(2*y)))
                x, y = new_back_im.size # get shape
                x2, y2 = xxx.size
                #xxx.show()
                #new_back_im.show()
                new_back_im.paste(xxx, (int(x/2)-int(x2/2), int(y/2)-int(y2/2)),xxx ) # paste at center of image
                new_back_im.save('C:/Users/ShepDaddy/Documents/GitHub/scantAI/augmented/augmentedImages/'+tick+'/'+str(numba)+'_'+back_name+'_'+str(rotation)+'.jpg')
    except:
        continue

# %%
import shutil
count = 0
for i in os.listdir('C:/Users/ShepDaddy/Documents/GitHub/scantAI/augmented/augmentedImages/train/Amblyommaamericanum'):
    
    if len(os.listdir('C:/Users/ShepDaddy/Documents/GitHub/scantAI/augmented/augmentedImages/train/Amblyommaamericanum')) <1001:

        break
    else:
        shutil.move('C:/Users/ShepDaddy/Documents/GitHub/scantAI/augmented/augmentedImages/train/Amblyommaamericanum/'+i, 'C:/Users/ShepDaddy/Documents/GitHub/scantAI/augmented/augmentedImages/validation/Ambloyommaamericanum')

for i in os.listdir('C:/Users/ShepDaddy/Documents/GitHub/scantAI/augmented/augmentedImages/train/Dermacentorvariabilis'):
    #count += 1
    if len(os.listdir('C:/Users/ShepDaddy/Documents/GitHub/scantAI/augmented/augmentedImages/train/Dermacentorvariabilis')) <1001:

        break
    else:
        shutil.move('C:/Users/ShepDaddy/Documents/GitHub/scantAI/augmented/augmentedImages/train/Dermacentorvariabilis/'+i, 'C:/Users/ShepDaddy/Documents/GitHub/scantAI/augmented/augmentedImages/validation/Dermacentorvariabilis')

for i in os.listdir('C:/Users/ShepDaddy/Documents/GitHub/scantAI/augmented/augmentedImages/train/Ixodesscapularis'):
    #count += 1
    if len(os.listdir('C:/Users/ShepDaddy/Documents/GitHub/scantAI/augmented/augmentedImages/train/Ixodesscapularis')) <1001:

        break
    else:
        shutil.move('C:/Users/ShepDaddy/Documents/GitHub/scantAI/augmented/augmentedImages/train/Ixodesscapularis/'+i, 'C:/Users/ShepDaddy/Documents/GitHub/scantAI/augmented/augmentedImages/validation/Ixodesscapularis')

# %%
df['name'].unique()
# Out:
# array(['Ixodesscapularis', 'Amblyommaamericanum', 'Ixodespacificus',
#        'Dermacentorvariabilis', 'Dermacentorandersoni', 'Ixodescookei',
#        'Ixodesricinus', 'Ixodesspp.', 'Amblyommamaculatum'], dtype=object)

# %%
import pandas as pd

df2 = pd.read_csv('sexy.csv')
#df2.set_index('number')
#print(df2.head)
#print(df2.loc('number'))
for ID in df2.index:
    # print(ID, type(ID))
    tick = df2.iloc[ID]['name']
    #print(tick)
# Out:
# Ixodesscapularis
# Amblyommaamericanum
# Ixodesscapularis
# Ixodesscapularis
# Ixodesscapularis
# Ixodesscapularis
# Amblyommaamericanum
# Amblyommaamericanum
# Amblyommaamericanum
# Amblyommaamericanum
# Amblyommaamericanum
# Ixodespacificus
# Ixodesscapularis
# Ixodesscapularis
# Ixodesscapularis
# Dermacentorvariabilis
# Amblyommaamericanum
# Ixodesscapularis
# Amblyommaamericanum
# Ixodesscapularis
# Dermacentorvariabilis
# Amblyommaamericanum
# Ixodesscapularis
# Amblyommaamericanum
# Ixodesscapularis
# Amblyommaamericanum
# Dermacentorvariabilis
# Dermacentorvariabilis
# Dermacentorvariabilis
# Amblyommaamericanum
# Dermacentorvariabilis
# Dermacentorvariabilis
# Dermacentorvariabilis
# Amblyommaamericanum
# Dermacentorandersoni
# Dermacentorvariabilis
# Dermacentorvariabilis
# Ixodesscapularis
# Ixodesscapularis
# Ixodesscapularis
# Amblyommaamericanum
# Ixodespacificus
# Dermacentorvariabilis
# Dermacentorvariabilis
# Amblyommaamericanum
# Ixodescookei
# Ixodesscapularis
# ...
